# %%
import PyPDF2
import nltk
from nltk import word_tokenize, pos_tag, ne_chunk
from nltk.tokenize import sent_tokenize

# %%
# Download NLTK resources (run this only once)
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')

# %%
pip install svgling

# %%
def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ''
        for page in reader.pages:
            text += page.extract_text ()
        return text

def chunk_text(text):
    sentences = sent_tokenize(text)
    tokenized_sentences = [word_tokenize(sent) for sent in sentences]
    tagged_sentences = [pos_tag(sent) for sent in tokenized_sentences]
    
    chunked_sentences = []
    for tagged_sentence in tagged_sentences:
        chunked_sentence = ne_chunk(tagged_sentence)
        chunked_sentences.append(chunked_sentence)
    
    return chunked_sentences

# Replace with your PDF file path
pdf_file_path = 'Big Data and BI - ICA - 2022 (1).pdf'

# Extract text from the PDF file
extracted_text = extract_text_from_pdf(pdf_file_path)

# Perform chunking on the extracted text
chunked_text = chunk_text(extracted_text)

# Display the chunked text
for sentence in chunked_text:
    print(sentence)
# Out:
# (S
#   (ORGANIZATION ICA/NNP)
#   Specification/NNP
#   (PERSON Annalisa/NNP Occhipinti/NNP Page/NNP)
#   |/VBD
#   1/CD
#   Module/NNP
#   Title/NNP
#   :/:
#   Big/NNP
#   Data/NNP
#   and/CC
#   (ORGANIZATION Business/NNP Intelligence/NNP Module/NNP)
#   Leader/NNP
#   :/:
#   Dr/NNP
#   (PERSON Annalisa/NNP Occhipinti/NNP Module/NNP Code/NNP)
#   :/:
#   (ORGANIZATION CIS4008/NNP)
#   -N/NNP
#   Assignment/NNP
#   Title/NNP
#   :/:
#   (PERSON Business/NN Intelligence/NNP Solution/NNP)
#   and/CC
#   (ORGANIZATION Report/NNP Deadline/NNP)
#   Date/NNP
#   :/:
#   11/01/202/CD
#   3/CD
#   Deadline/JJ
#   Time/NN
#   :/:
#   4:00pm/CD
#   Submission/NNP
#   Method/NNP
#   :/:
#   (GPE Online/NNP)
#   (/(
#   (ORGANIZATION Blackboard/NNP)
#   )/)
#   /VBP
#   (ORGANIZATION Middlesbrough/NNP Tower/NNP)
#   /NNP
#   Library/NNP
#   Support/NNP
#   for/IN
#   (ORGANIZATION Academic/NNP Skills/NNP)
#   Did/NNP
#   you/PRP
#   know/VBP
#   you/PRP
#   can/MD
#   book/NN
#   an/DT
#   individual/JJ
#   30/CD
#   minute/JJ
#   tutorial/NN
#   in/IN
#   the/DT
#   (ORGANIZATION Learning/NNP Hub/NNP)
#   with/IN
#   an/DT
#   adviser/NN
#   to/TO
#   help/VB
#   you/PRP
#   with/IN
#   your/PRP$
#   academic/JJ
#   skills/NNS
#   ,/,
#   writing/VBG
#   or/CC
#   numeracy/NN
#   ?/.)
# (S
#   Or/CC
#   that/IN
#   there/EX
#   are/VBP
#   loEDT/JJR
#   of/IN
#   really/RB
#   useful/JJ
#   workshops/NNS
#   available/JJ
#   to/TO
#   help/VB
#   you/PRP
#   with/IN
#   your/PRP$
#   studies/NNS
#   and/CC
#   assessments/NNS
#   ?/.)
# (S
#   Have/VBP
#   a/DT
#   look/NN
#   at/IN
#   the/DT
#   (ORGANIZATION Succeed/NNP)
#   @/NNP
#   Tees/NNP
#   workshops/VBZ
#   for/IN
#   more/JJR
#   details/NNS
#   ./.)
# (S
#   (ORGANIZATION FULL/NNP)
#   (ORGANIZATION DETAILS/NNP OF/IN)
#   (ORGANIZATION THE/NNP)
#   (ORGANIZATION ASSIGNMENT/NNP)
#   ARE/NNP
#   ATTACHED/NNP
#   INCLUDING/NNP
#   MARKING/NNP
#   &/CC
#   (ORGANIZATION GRADING/NNP)
#   CRITERIA/NNP
#   (ORGANIZATION ICA/NNP)
#   SPECIFICATION/NNP
#   Central/NNP
#   Assignments/NNP
#   Office/NNP
#   (/(
#   (ORGANIZATION Middlesbrough/NNP Tower/NNP)
#   M2.08/NNP
#   )/)
#   Notes/VBZ
#   :/:
#   •/NN
#   All/DT
#   work/NN
#   (/(
#   including/VBG
#   (ORGANIZATION CDs/NNP)
#   etc/NN
#   )/)
#   needs/VBZ
#   to/TO
#   be/VB
#   secured/VBN
#   in/IN
#   a/DT
#   plastic/JJ
#   envelope/NN
#   or/CC
#   a/DT
#   folder/NN
#   and/CC
#   clearly/RB
#   marked/VBN
#   with/IN
#   the/DT
#   student/NN
#   name/NN
#   ,/,
#   number/NN
#   and/CC
#   module/JJ
#   title/NN
#   ./.)
# (S
#   •/VB
#   An/DT
#   (ORGANIZATION Assignment/NNP Front/NNP Sheet/NNP)
#   should/MD
#   be/VB
#   fully/RB
#   completed/VBN
#   before/IN
#   the/DT
#   work/NN
#   is/VBZ
#   submitted/VBN
#   ./.)
# (S
#   •/NN
#   When/WRB
#   an/DT
#   extension/NN
#   has/VBZ
#   been/VBN
#   granted/VBN
#   ,/,
#   a/DT
#   fully/RB
#   completed/VBN
#   and/CC
#   signed/VBN
#   Extension/NNP
#   form/NN
#   must/MD
#   be/VB
#   submitted/VBN
#   to/TO
#   the/DT
#   (ORGANIZATION SCMA/NNP Reception/NNP)
#   ./.)
# (S
#   (PERSON Online/JJ)
#   (ORGANIZATION Submission/NNP)
#   Notes/NNS
#   :/:
#   •/NN
#   Please/NNP
#   follow/VB
#   carefully/RB
#   the/DT
#   instructions/NNS
#   given/VBN
#   on/IN
#   the/DT
#   (ORGANIZATION Assignment/NNP Specification/NNP)
#   •/NNP
#   When/WRB
#   an/DT
#   extension/NN
#   has/VBZ
#   been/VBN
#   granted/VBN
#   ,/,
#   a/DT
#   fully/RB
#   completed/VBN
#   and/CC
#   signed/VBN
#   Extension/NNP
#   form/NN
#   must/MD
#   be/VB
#   submitted/VBN
#   to/TO
#   the/DT
#   (ORGANIZATION SCMA/NNP Reception/NNP)
#   ./.)
# (S
#   (ORGANIZATION ICA/NNP)
#   Specification/NNP
#   (PERSON Annalisa/NNP Occhipinti/NNP Page/NNP)
#   |/VBD
#   2/CD
#   Big/NNP
#   Data/NNP
#   and/CC
#   (ORGANIZATION Business/NNP Intelligence/NNP)
#   CIS4/NNP
#   008-N/JJ
#   In-course/NNP
#   Assessment/NNP
#   “/NNP
#   Business/NNP
#   Intelligence/NNP
#   (/(
#   BI/NNP
#   )/)
#   is/VBZ
#   the/DT
#   use/NN
#   of/IN
#   computing/VBG
#   technologies/NNS
#   ,/,
#   applications/NNS
#   ,/,
#   and/CC
#   practices/NNS
#   for/IN
#   the/DT
#   collection/NN
#   ,/,
#   integration/NN
#   ,/,
#   analysis/NN
#   ,/,
#   and/CC
#   presentation/NN
#   of/IN
#   business/NN
#   information/NN
#   ./.)
# (S
#   (ORGANIZATION Business/NN)
#   (ORGANIZATION Intelligence/NNP)
#   solutions/NNS
#   provide/VBP
#   current/JJ
#   ,/,
#   historical/JJ
#   ,/,
#   and/CC
#   predictive/JJ
#   views/NNS
#   of/IN
#   internally/RB
#   structured/VBN
#   data/NNS
#   for/IN
#   pro/JJ
#   ducts/NNS
#   and/CC
#   departments/NNS
#   by/IN
#   establishing/VBG
#   more/RBR
#   effective/JJ
#   decision/NN
#   -making/VBG
#   and/CC
#   strategic/JJ
#   operational/JJ
#   insights./NN
#   ”/NN
#   For/IN
#   this/DT
#   In/IN
#   -Course/JJ
#   Assessment/NNP
#   (/(
#   (ORGANIZATION ICA/NNP)
#   )/)
#   you/PRP
#   are/VBP
#   required/VBN
#   to/TO
#   design/VB
#   and/CC
#   implement/VB
#   a/DT
#   (ORGANIZATION Business/NNP Intelligence/NNP)
#   (/(
#   BI/NNP
#   )/)
#   Solution/NN
#   from/IN
#   an/DT
#   (GPE Industry/NN)
#   -based/VBD
#   (PERSON Dataset/NNP)
#   using/VBG
#   (PERSON Microsoft/NNP Power/NNP BI/NNP)
#   ./.)
# (S
#   The/DT
#   assessment/NN
#   is/VBZ
#   individual/JJ
#   ,/,
#   and/CC
#   y/PRP
#   ou/PRP
#   are/VBP
#   required/VBN
#   to/TO
#   produce/VB
#   a/DT
#   (ORGANIZATION Business/NNP Intelligence/NNP)
#   Report/NNP
#   */NNP
#   coveri/VBZ
#   ng/FW
#   a/DT
#   BI/NNP
#   Design/NNP
#   and/CC
#   (ORGANIZATION Solution/NNP)
#   ./.)
# (S
#   */JJ
#   Report/NNP
#   :/:
#   The/DT
#   term/NN
#   report/NN
#   is/VBZ
#   used/VBN
#   to/TO
#   denote/VB
#   a/DT
#   Word/NNP
#   document/NN
#   to/TO
#   present/VB
#   part/NN
#   of/IN
#   the/DT
#   design/NN
#   and/CC
#   implementation/NN
#   of/IN
#   your/PRP$
#   BI/NNP
#   Solution/NN
#   with/IN
#   the/DT
#   supporting/VBG
#   artefacts/NNS
#   (/(
#   files/NNS
#   )/)
#   ./.)
# (S
#   The/DT
#   report/NN
#   should/MD
#   mainly/RB
#   consist/VB
#   of/IN
#   images/NNS
#   or/CC
#   screenshots/NNS
#   with/IN
#   wording/VBG
#   kept/VBN
#   in/IN
#   bullet/NN
#   points/NNS
#   or/CC
#   summative/JJ
#   ./.)
# (S
#   The/DT
#   report/NN
#   is/VBZ
#   to/TO
#   be/VB
#   at/IN
#   least/JJS
#   1200/CD
#   words/NNS
#   and/CC
#   includes/VBZ
#   the/DT
#   following/JJ
#   sections/NNS
#   ./.)
# (S
#   (ORGANIZATION ICA/NNP)
#   –/NNP
#   Business/NNP
#   Report/NNP
#   Your/NNP
#   written/VBN
#   report/NN
#   will/MD
#   be/VB
#   used/VBN
#   to/TO
#   present/VB
#   the/DT
#   completed/VBN
#   data/NN
#   analytics/NNS
#   and/CC
#   data/NNS
#   visualisation/NN
#   phases/NNS
#   of/IN
#   your/PRP$
#   Power/NNP
#   BI/NNP
#   solution/NN
#   ./.)
# (S
#   You/PRP
#   will/MD
#   need/VB
#   to/TO
#   demonstrate/VB
#   your/PRP$
#   ability/NN
#   to/TO
#   build/VB
#   a/DT
#   (ORGANIZATION Business/NNP Intelligence/NNP Solution/NNP)
#   and/CC
#   present/VB
#   your/PRP$
#   dashbo/NN
#   ard/IN
#   analytics/NNS
#   ,/,
#   visualisation/NN
#   ,/,
#   and/CC
#   findings/NNS
#   in/IN
#   a/DT
#   (ORGANIZATION Business/NNP Report/NNP)
#   ,/,
#   including/VBG
#   the/DT
#   following/JJ
#   section/NN
#   s/NNS
#   :/:
#   •/JJ
#   Title/NNP
#   page/NN
#   This/DT
#   will/MD
#   include/VB
#   the/DT
#   title/NN
#   of/IN
#   your/PRP$
#   report/NN
#   ,/,
#   project/NN
#   and/CC
#   your/PRP$
#   details/NNS
#   (/(
#   this/DT
#   can/MD
#   be/VB
#   the/DT
#   same/JJ
#   as/IN
#   the/DT
#   title/NN
#   page/NN
#   of/IN
#   the/DT
#   first/JJ
#   section/NN
#   )/)
#   ./.)
# (S
#   •/JJ
#   Executive/NNP
#   Summary/NNP
#   This/DT
#   is/VBZ
#   a/DT
#   condensed/JJ
#   versi/NN
#   on/IN
#   of/IN
#   your/PRP$
#   report/NN
#   ./.)
# (S
#   To/TO
#   help/VB
#   busy/JJ
#   people/NNS
#   understand/VBP
#   what/WP
#   the/DT
#   problem/NN
#   is/VBZ
#   ,/,
#   the/DT
#   executive/NN
#   summary/NN
#   includes/VBZ
#   the/DT
#   key/JJ
#   findings/NNS
#   and/CC
#   your/PRP$
#   recommendations/NNS
#   ./.)
# (S
#   It/PRP
#   is/VBZ
#   common/JJ
#   practice/NN
#   to/TO
#   include/VB
#   one/CD
#   or/CC
#   two/CD
#   charts/NNS
#   from/IN
#   the/DT
#   full/JJ
#   report/NN
#   ./.)
# (S
#   •/NN
#   Body/NNP
#   o/VBZ
#   Introduction/NNP
#   This/DT
#   will/MD
#   illustrate/VB
#   the/DT
#   questions/NNS
#   you/PRP
#   are/VBP
#   addressing/VBG
#   in/IN
#   your/PRP$
#   report/NN
#   and/CC
#   will/MD
#   give/VB
#   some/DT
#   information/NN
#   about/IN
#   the/DT
#   data/NNS
#   collected/VBN
#   ./.)
# (S
#   This/DT
#   section/NN
#   can/MD
#   be/VB
#   shorter/JJR
#   (ORGANIZATION
#     ICA/NNP
#     Specification/NNP
#     Annalisa/NNP
#     Occhipinti/NNP
#     Page/NNP)
#   |/VBD
#   3/CD
#   than/IN
#   usual/JJ
#   considering/VBG
#   that/IN
#   you/PRP
#   might/MD
#   be/VB
#   working/VBG
#   with/IN
#   sample/JJ
#   data/NNS
#   ./.)
# (S
#   However/RB
#   ,/,
#   try/VB
#   your/PRP$
#   best/JJS
#   to/TO
#   “/VB
#   pretend/VB
#   ”/NN
#   that/IN
#   your/PRP$
#   data/NNS
#   comes/VBZ
#   from/IN
#   a/DT
#   real/JJ
#   business/NN
#   and/CC
#   introduce/VB
#   the/DT
#   challenges/NNS
#   that/IN
#   the/DT
#   business/NN
#   would/MD
#   like/VB
#   to/TO
#   address/VB
#   through/IN
#   your/PRP$
#   analysis/NN
#   ./.)
# (S
#   Your/PRP$
#   introduction/NN
#   must/MD
#   contain/VB
#   the/DT
#   two/CD
#   sub/NN
#   -sections/NNS
#   below/IN
#   1/CD
#   ./.)
# (S
#   (GPE Data/NNP)
#   (PERSON Source/NN)
#   :/:
#   What/WP
#   are/VBP
#   the/DT
#   sources/NNS
#   of/IN
#   the/DT
#   data/NN
#   or/CC
#   where/WRB
#   does/VBZ
#   the/DT
#   data/NNS
#   originate/NN
#   from/IN
#   ?/.)
# (S A/DT description/NN of/IN the/DT dataset/NN selected/VBN ./.)
# (S
#   This/DT
#   includes/VBZ
#   the/DT
#   data/NN
#   source/NN
#   ,/,
#   provided/VBN
#   as/IN
#   a/DT
#   link/NN
#   ,/,
#   database/NN
#   name/NN
#   ,/,
#   tables/NNS
#   name/NN
#   and/CC
#   column/NN
#   name/NN
#   ./.)
# (S 2/CD ./.)
# (S
#   BI/NNP
#   Requirements/NNP
#   \Questions/NNS
#   :/:
#   The/DT
#   (ORGANIZATION BI/NNP Questions/NNP)
#   will/MD
#   help/VB
#   determine/VB
#   the/DT
#   (ORGANIZATION Key/NNP Performance/NNP)
#   Indicator/NNP
#   (/(
#   (ORGANIZATION KPI/NNP)
#   )/)
#   for/IN
#   analytics/NNS
#   and/CC
#   visuals/NNS
#   ./.)
# (S
#   This/DT
#   is/VBZ
#   intended/VBN
#   as/IN
#   a/DT
#   high/JJ
#   -level/NNP
#   scope/NN
#   of/IN
#   the/DT
#   initial/JJ
#   discovery/NN
#   in/IN
#   order/NN
#   to/TO
#   present/VB
#   an/DT
#   understanding/NN
#   of/IN
#   the/DT
#   following/NN
#   :/:
#   •/VB
#   What/WP
#   business/NN
#   processes/NNS
#   are/VBP
#   most/RBS
#   critical/JJ
#   to/TO
#   measure/VB
#   -/:
#   (ORGANIZATION KPI/NNP)
#   ?/.)
# (S
#   •/VB
#   What/WP
#   kinds/VBZ
#   of/IN
#   business/NN
#   questions/problems/NNS
#   are/VBP
#   you/PRP
#   trying/VBG
#   to/TO
#   answer/solve/VB
#   ?/.)
# (S
#   •/NN
#   Who/WP
#   are/VBP
#   the/DT
#   key/JJ
#   user/NN
#   groups/NNS
#   of/IN
#   this/DT
#   data/report/NN
#   ?/.)
# (S •/JJ Why/WRB is/VBZ this/DT information/NN needed/VBN ?/.)
# (S
#   (/(
#   Think/VB
#   about/IN
#   the/DT
#   broader/JJR
#   process/NN
#   )/)
#   o/NN
#   Finding/VBG
#   based/VBN
#   on/IN
#   analysis/NN
#   and/CC
#   evaluation/NN
#   This/DT
#   section/NN
#   will/MD
#   cover/VB
#   the/DT
#   key/JJ
#   findings/NNS
#   based/VBN
#   on/IN
#   analysis/NN
#   and/CC
#   evaluation/NN
#   :/:
#   this/DT
#   is/VBZ
#   the/DT
#   most/RBS
#   import/JJ
#   ant/JJ
#   section/NN
#   of/IN
#   your/PRP$
#   (ORGANIZATION ICA/NNP)
#   ./.)
# (S
#   This/DT
#   section/NN
#   must/MD
#   include/VB
#   :/:
#   (/(
#   1/CD
#   )/)
#   your/PRP$
#   Power/NNP
#   BI/NNP
#   visuals/NNS
#   with/IN
#   the/DT
#   description/NN
#   of/IN
#   the/DT
#   type/NN
#   of/IN
#   data/NNS
#   you/PRP
#   are/VBP
#   displaying/VBG
#   and/CC
#   why/WRB
#   you/PRP
#   are/VBP
#   using/VBG
#   such/JJ
#   metrics/NNS
#   ./.)
# (S
#   Screenshots/NNS
#   and/CC
#   description/NN
#   of/IN
#   each/DT
#   Power/NNP
#   BI/NNP
#   visuals/NNS
#   must/MD
#   be/VB
#   included/VBN
#   ./.)
# (S
#   (/(
#   2/CD
#   )/)
#   the/DT
#   key/JJ
#   findings/NNS
#   from/IN
#   the/DT
#   charts/NNS
#   must/MD
#   be/VB
#   discussed/VBN
#   ./.)
# (S
#   •/JJ
#   Conclusions/NNP
#   and/CC
#   (PERSON Recommendations/NNP Summarise/NNP)
#   your/PRP$
#   report/NN
#   and/CC
#   provide/VB
#   some/DT
#   recommendations/NNS
#   based/VBN
#   on/IN
#   your/PRP$
#   findings/NNS
#   ./.)
# (S
#   (ORGANIZATION ICA/NNP)
#   –/NNP
#   Appendix/NNP
#   :/:
#   BI/NNP
#   Design/NNP
#   Your/NNP
#   written/VBN
#   report/NN
#   must/MD
#   have/VB
#   an/DT
#   appendix/NN
#   with/IN
#   the/DT
#   following/JJ
#   sections/NNS
#   ./.)
# (S 1/CD ./.)
# (S
#   (PERSON Data/NNP)
#   Pre/NNP
#   -Processing/NN
#   or/CC
#   (PERSON Data/NNP Cleansing/NNP)
#   •/VBZ
#   A/DT
#   description/NN
#   of/IN
#   the/DT
#   data/NNS
#   pre/NN
#   -processing/VBG
#   steps/NNS
#   ./.)
# (S
#   This/DT
#   will/MD
#   include/VB
#   any/DT
#   steps/NNS
#   performed/VBN
#   to/TO
#   cleanse/VB
#   your/PRP$
#   data/NNS
#   ,/,
#   such/JJ
#   as/IN
#   removing/VBG
#   (ORGANIZATION NAs/NNP)
#   ,/,
#   renaming/VBG
#   columns/NN
#   ,/,
#   changing/VBG
#   data/NNS
#   types/NNS
#   ,/,
#   removing/VBG
#   errors/NNS
#   ,/,
#   removing/VBG
#   columns/NN
#   ,/,
#   merging/VBG
#   tables/NNS
#   etc/FW
#   ./.)
# (S
#   This/DT
#   can/MD
#   be/VB
#   provided/VBN
#   as/IN
#   a/DT
#   bullet/NN
#   list/NN
#   ./.)
# (S
#   •/NN
#   You/PRP
#   should/MD
#   include/VB
#   screenshots/NNS
#   of/IN
#   your/PRP$
#   Power/NNP
#   BI/NNP
#   project/NN
#   in/IN
#   your/PRP$
#   presentation/NN
#   to/TO
#   illustrate/VB
#   the/DT
#   final/JJ
#   effects/NNS
#   of/IN
#   each/DT
#   pre/NN
#   -processing/VBG
#   step/NN
#   ./.)
# (S
#   Only/RB
#   a/DT
#   screenshot/NN
#   of/IN
#   the/DT
#   results/NNS
#   of/IN
#   the/DT
#   preprocessing/JJ
#   steps/NNS
#   is/VBZ
#   required/VBN
#   ./.)
# (S
#   There/EX
#   is/VBZ
#   no/DT
#   need/NN
#   to/TO
#   add/VB
#   screenshots/NNS
#   of/IN
#   the/DT
#   process/NN
#   (/(
#   you/PRP
#   do/VBP
#   not/RB
#   need/VB
#   to/TO
#   include/VB
#   the/DT
#   steps/NNS
#   of/IN
#   right/JJ
#   -clicking/VBG
#   on/IN
#   a/DT
#   column/NN
#   or/CC
#   clicking/VBG
#   a/DT
#   specific/JJ
#   button/NN
#   )/)
#   ./.)
# (S
#   (ORGANIZATION ICA/NNP)
#   Specification/NNP
#   (PERSON Annalisa/NNP Occhipinti/NNP Page/NNP)
#   |/VBD
#   4/CD
#   2/CD
#   ./.)
# (S
#   BI/NNP
#   Data/NNP
#   Modelling/NNP
#   via/IN
#   (PERSON Star/NNP Schema/NNP)
#   -/:
#   Facts/NNS
#   and/CC
#   (GPE Dimensions/NNP)
#   ./.)
# (S
#   •/NNS
#   Using/VBG
#   your/PRP$
#   BI/NNP
#   questions/NNS
#   ,/,
#   identify/VB
#   a/DT
#   suitable/JJ
#   data/NNS
#   model/NN
#   from/IN
#   your/PRP$
#   dataset/NN
#   and/CC
#   present/JJ
#   it/PRP
#   as/IN
#   (PERSON Star/NNP)
#   or/CC
#   (PERSON Snowflake/NNP Schema/NNP)
#   using/VBG
#   (PERSON Fact/NNP)
#   and/CC
#   (PERSON Dimension/NNP Tables/NNP)
#   ./.)
# (S
#   •/NN
#   You/PRP
#   should/MD
#   include/VB
#   screenshots/NNS
#   of/IN
#   the/DT
#   final/JJ
#   (ORGANIZATION Star/NNP Schema/NNP)
#   data/NNS
#   model/NN
#   with/IN
#   facts/NNS
#   and/CC
#   dimensions/NNS
#   from/IN
#   your/PRP$
#   Power/NNP
#   BI/NNP
#   project/NN
#   to/TO
#   illustrate/VB
#   the/DT
#   effect/NN
#   of/IN
#   the/DT
#   data/NNS
#   model/NN
#   ling/VBG
#   process/NN
#   ./.)
# (S
#   Only/RB
#   a/DT
#   before/NN
#   and/CC
#   after/IN
#   screenshot/JJ
#   must/MD
#   be/VB
#   included/VBN
#   ./.)
# (S
#   The/DT
#   keys/NNS
#   connecting/VBG
#   the/DT
#   tables/NNS
#   must/MD
#   be/VB
#   highlighted/VBN
#   or/CC
#   explained/VBN
#   ./.)
# (S 3/CD ./.)
# (S
#   (ORGANIZATION DAX/NNP)
#   and/CC
#   M/NNP
#   Language/NNP
#   •/NNP
#   Describe/NNP
#   any/DT
#   Measures/NNP
#   and/CC
#   /or/NNP
#   Calculated/NNP
#   (PERSON Columns/NNP)
#   added/VBD
#   using/VBG
#   (ORGANIZATION DAX/NNP)
#   ./.)
# (S
#   •/NN
#   (PERSON Explain/NNP)
#   where/WRB
#   M/NNP
#   Language/NNP
#   has/VBZ
#   been/VBN
#   used/VBN
#   in/IN
#   your/PRP$
#   report/NN
#   and/CC
#   how/WRB
#   ./.)
# (S 4/CD ./.)
# (S
#   (PERSON Dashboard/NNP)
#   •/NNP
#   Describe/NNP
#   the/DT
#   (ORGANIZATION Power/NNP)
#   BI/NNP
#   dashboard/NN
#   (/(
#   full/JJ
#   collection/NN
#   of/IN
#   visuals/NNS
#   )/)
#   and/CC
#   how/WRB
#   the/DT
#   content/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Power/NNP)
#   BI/NNP
#   pages/NNS
#   is/VBZ
#   organised/VBN
#   ./.)
# (S
#   •/VB
#   A/DT
#   screenshot/NN
#   of/IN
#   all/PDT
#   the/DT
#   pages/NNS
#   in/IN
#   the/DT
#   (ORGANIZATION Dashboard/NNP)
#   must/MD
#   be/VB
#   provided/VBN
#   ./.)
# (S
#   This/DT
#   will/MD
#   assess/VB
#   the/DT
#   student/NN
#   ’/NNP
#   s/VBZ
#   ability/NN
#   to/TO
#   demonstrate/VB
#   data/NNS
#   analytics/NNS
#   ,/,
#   visualisati/NN
#   on/IN
#   and/CC
#   reporting/VBG
#   skills/NNS
#   required/VBN
#   to/TO
#   support/VB
#   any/DT
#   (ORGANIZATION Business/NNP Intelligence/NNP)
#   solution/NN
#   (/(
#   assess/JJ
#   Learning/NNP
#   Outcome/NNP
#   1/CD
#   ,/,
#   3/CD
#   ,/,
#   4/CD
#   ,/,
#   5/CD
#   ,/,
#   6/CD
#   &/CC
#   7/CD
#   )/)
#   A/DT
#   template/NN
#   with/IN
#   the/DT
#   sections/NNS
#   listed/VBN
#   above/RB
#   is/VBZ
#   available/JJ
#   on/IN
#   (ORGANIZATION Blackboard/NNP)
#   ./.)
# (S
#   (GPE Submission/NN)
#   details/NNS
#   You/PRP
#   will/MD
#   need/VB
#   to/TO
#   submit/VB
#   the/DT
#   following/JJ
#   files/NNS
#   :/:
#   1/CD
#   ./.)
# (S
#   The/DT
#   written/VBN
#   report/NN
#   file/NN
#   (/(
#   one/CD
#   single/JJ
#   (ORGANIZATION PDF/NNP)
#   file/NN
#   containing/VBG
#   both/CC
#   the/DT
#   written/VBN
#   report/NN
#   and/CC
#   the/DT
#   appendix/NN
#   )/)
#   ./.)
# (S 2/CD ./.)
# (S The/DT (ORGANIZATION Power/NNP) BI/NNP project/NN file/NN ./.)
# (S 3/CD ./.)
# (S
#   Any/DT
#   Excel/NNP
#   or/CC
#   .csv/NNP
#   file/NN
#   s/NN
#   used/VBN
#   to/TO
#   import/VB
#   the/DT
#   data/NNS
#   ./.)
# (S
#   A/DT
#   submission/NN
#   link/NN
#   will/MD
#   be/VB
#   available/JJ
#   via/IN
#   (ORGANIZATION Blackboard/NNP)
#   under/IN
#   the/DT
#   (ORGANIZATION Assessments/NNP)
#   link/NN
#   ./.)
# (S
#   You/PRP
#   must/MD
#   submit/VB
#   your/PRP$
#   files/NNS
#   by/IN
#   the/DT
#   due/JJ
#   date/NN
#   reported/VBD
#   on/IN
#   the/DT
#   front/JJ
#   page/NN
#   of/IN
#   this/DT
#   document/NN
#   ./.)
# (S
#   Use/VB
#   the/DT
#   following/JJ
#   naming/NN
#   convention/NN
#   studentnumber_lastname/NN
#   ./.)
# (S firstname/NN ./.)
# (S pdf/NN (/( e.g/NN ./.)
# (S
#   x1234567_smith/NNP
#   .pdf/NNP
#   )/)
#   (PERSON Please/NNP)
#   also/RB
#   make/VBP
#   sure/JJ
#   that/IN
#   submitted/VBN
#   documentation/NN
#   has/VBZ
#   been/VBN
#   tested/VBN
#   and/CC
#   verified/VBN
#   and/CC
#   is/VBZ
#   not/RB
#   corrupted/VBN
#   in/IN
#   any/DT
#   way/NN
#   which/WDT
#   would/MD
#   prevent/VB
#   access/NN
#   for/IN
#   marking/VBG
#   ./.)
# (S
#   Feedback/NNP
#   You/PRP
#   will/MD
#   receive/VB
#   your/PRP$
#   feedback/NN
#   within/IN
#   20/CD
#   working/VBG
#   days/NNS
#   from/IN
#   the/DT
#   submission/NN
#   deadline/NN
#   ./.)
# (S
#   (ORGANIZATION ICA/NNP)
#   Specification/NNP
#   (PERSON Annalisa/NNP Occhipinti/NNP Page/NNP)
#   |/VBD
#   5/CD
#   Learning/NNP
#   Outcomes/NNPS
#   This/DT
#   assessment/NN
#   has/VBZ
#   been/VBN
#   designed/VBN
#   to/TO
#   assess/VB
#   the/DT
#   following/VBG
#   learning/NN
#   outcomes/NNS
#   :/:
#   Personal/NNP
#   and/CC
#   (ORGANIZATION Transferable/NNP)
#   Skills/NNP
#   1/CD
#   ./.)
# (S
#   (GPE Reflect/NN)
#   on/IN
#   and/CC
#   critically/RB
#   appraise/VB
#   own/JJ
#   performance/NN
#   and/CC
#   skills/NNS
#   development/NN
#   during/IN
#   the/DT
#   module/NN
#   ./.)
# (S
#   (GPE Research/NN)
#   ,/,
#   (PERSON Knowledge/NNP)
#   and/CC
#   (PERSON Cognitive/NNP Skills/NNP)
#   2/CD
#   ./.)
# (S
#   (GPE Examine/NN)
#   and/CC
#   evaluate/NN
#   system/NN
#   -level/NNP
#   software/NN
#   architectures/NNS
#   ,/,
#   tools/NNS
#   and/CC
#   techniques/NNS
#   for/IN
#   big/JJ
#   data/NNS
#   systems/NNS
#   ./.)
# (S 3/CD ./.)
# (S
#   Demonstrate/VB
#   a/DT
#   critical/JJ
#   understanding/NN
#   of/IN
#   the/DT
#   issues/NNS
#   associated/VBN
#   with/IN
#   business/NN
#   intelligence/NN
#   and/CC
#   big/JJ
#   data/NNS
#   ./.)
# (S 4/CD ./.)
# (S
#   (ORGANIZATION Integrate/NNP)
#   and/CC
#   synthesise/VB
#   diverse/JJ
#   concepts/NNS
#   and/CC
#   theory/NN
#   on/IN
#   system/NN
#   -level/NNP
#   software/NN
#   architectures/NNS
#   for/IN
#   big/JJ
#   data/NNS
#   systems/NNS
#   to/TO
#   design/VB
#   the/DT
#   data/NN
#   processing/NN
#   requirements/NNS
#   of/IN
#   big/JJ
#   data/NNS
#   system/NN
#   s./VBD
#   5/CD
#   ./.)
# (S
#   Research/NNP
#   an/DT
#   emerging/VBG
#   database/NN
#   technology/NN
#   and/CC
#   communicate/VB
#   the/DT
#   findings/NNS
#   in/IN
#   writing/VBG
#   in/IN
#   an/DT
#   academic/JJ
#   context/NN
#   ./.)
# (S Professional/NNP Skills/NNP 6/CD ./.)
# (S
#   (GPE Select/NNP)
#   and/CC
#   implement/JJ
#   appropriate/JJ
#   BI/NNP
#   tools/NNS
#   and/CC
#   evaluate/VB
#   the/DT
#   results/NNS
#   of/IN
#   their/PRP$
#   application/NN
#   to/TO
#   a/DT
#   given/VBN
#   scenario/NN
#   ./.)
# (S 7/CD ./.)
# (S
#   Autonomously/RB
#   plan/NN
#   ,/,
#   design/NN
#   and/CC
#   implement/NN
#   a/DT
#   big/JJ
#   data/NN
#   system/NN
#   to/TO
#   meet/VB
#   an/DT
#   enterprise/NN
#   's/POS
#   information/NN
#   requirements/NNS
#   and/CC
#   business/NN
#   rules/NNS
#   for/IN
#   big/JJ
#   data/NNS
#   ./.)
# (S
#   (ORGANIZATION ICA/NNP)
#   Specification/NNP
#   (PERSON Annalisa/NNP Occhipinti/NNP Page/NNP)
#   |/VBD
#   6/CD
#   Assessment/NNP
#   Criteria/NNP
#   GRADE/NNP
#   Characteristics/NNP
#   of/IN
#   (GPE Response/NNP)
#   %/NN
#   :/:
#   70/CD
#   -100/NN
#   Marks/NNS
#   :/:
#   (/(
#   49/CD
#   -70/NN
#   )/)
#   70/CD
#   %/NN
#   +/JJ
#   [/NNP
#   professional/JJ
#   |/NNP
#   outstanding/JJ
#   ]/NNP
#   BI/NNP
#   Solution/NNP
#   and/CC
#   interpretation/NN
#   of/IN
#   the/DT
#   data/NN
#   was/VBD
#   undertaken/JJ
#   using/VBG
#   a/DT
#   dashboard/NN
#   approach/NN
#   employing/VBG
#   a/DT
#   suitable/JJ
#   software/NN
#   environment/NN
#   and/CC
#   graphical/JJ
#   presentation/NN
#   to/TO
#   highlight/VB
#   critical/JJ
#   elements/NNS
#   in/IN
#   the/DT
#   data/NN
#   ./.)
# (S
#   The/DT
#   dashboard/NN
#   provided/VBD
#   some/DT
#   dynamic/JJ
#   data/NNS
#   manipulation/NN
#   feat/NN
#   ures/NNS
#   and/CC
#   employed/VBD
#   a/DT
#   variety/NN
#   of/IN
#   supporting/VBG
#   statistical/JJ
#   calculations/NNS
#   and/CC
#   modelling/NN
#   ./.)
# (S
#   Supporting/VBG
#   reports/NNS
#   were/VBD
#   very/RB
#   well/RB
#   designed/VBN
#   and/CC
#   developed/VBN
#   and/CC
#   accompanied/VBN
#   by/IN
#   a/DT
#   well/NN
#   -developed/VBN
#   action/NN
#   agenda/NN
#   supporting/VBG
#   the/DT
#   DW-BI/JJ
#   Solution/NNP
#   ./.)
# (S
#   The/DT
#   (ORGANIZATION BI/NNP)
#   Design/NNP
#   report/NN
#   meets/NNS
#   (PERSON Microso/NNP)
#   ft/VBP
#   (PERSON Developer/NNP Network/NNP)
#   (/(
#   (ORGANIZATION MSDN/NNP)
#   )/)
#   and/CC
#   (GPE Industry/NNP)
#   standards/NNS
#   ./.)
# (S
#   The/DT
#   design/NN
#   is/VBZ
#   outstanding/JJ
#   and/CC
#   meets/VBZ
#   (ORGANIZATION ALL/NNP)
#   learning/VBG
#   outcomes/NNS
#   at/IN
#   an/DT
#   outstanding/JJ
#   level/NN
#   ./.)
# (S
#   (GPE Clear/JJ)
#   demonstration/NN
#   and/CC
#   outstanding/JJ
#   awareness/NN
#   of/IN
#   (ORGANIZATION DW/NNP)
#   and/CC
#   (ORGANIZATION BI/NNP)
#   needs/VBZ
#   for/IN
#   industry/NN
#   ./.)
# (S
#   All/DT
#   design/NN
#   steps/NNS
#   clearly/RB
#   identified/VBN
#   and/CC
#   of/IN
#   outstanding/JJ
#   quality/NN
#   ./.)
# (S
#   %/NN
#   :/:
#   50/CD
#   –/IN
#   69/CD
#   Marks/NNS
#   :/:
#   (/(
#   35/CD
#   -48/NN
#   )/)
#   [/FW
#   exemplary/JJ
#   ]/NN
#   BI/NNP
#   Solution/NNP
#   of/IN
#   the/DT
#   data/NN
#   was/VBD
#   undertaken/VBN
#   using/VBG
#   some/DT
#   simple/JJ
#   statistical/JJ
#   processing/NN
#   and/CC
#   calculation/NN
#   ,/,
#   but/CC
#   it/PRP
#   could/MD
#   be/VB
#   significantly/RB
#   enhanced/VBN
#   with/IN
#   a/DT
#   more/RBR
#   in/IN
#   -depth/NNP
#   statistical/JJ
#   DW/NNP
#   -BI/NNP
#   Solution/NNP
#   and/CC
#   by/IN
#   using/VBG
#   a/DT
#   suitable/JJ
#   software/NN
#   tool/NN
#   ./.)
# (S
#   Results/NNS
#   of/IN
#   the/DT
#   DW-BI/NNP
#   Solution/NNP
#   and/CC
#   proposals/NNS
#   for/IN
#   a/DT
#   responsive/JJ
#   action/NN
#   could/MD
#   also/RB
#   be/VB
#   more/JJR
#   considered/VBN
#   ./.)
# (S
#   Supporting/VBG
#   reports/NNS
#   were/VBD
#   acceptable/JJ
#   but/CC
#   would/MD
#   benefit/VB
#   from/IN
#   more/JJR
#   considered/VBN
#   and/CC
#   detailed/VBN
#   content/NN
#   ./.)
# (S
#   The/DT
#   (ORGANIZATION BRS/NNP)
#   report/NN
#   meets/VBZ
#   most/JJS
#   of/IN
#   (ORGANIZATION MSDN/NNP)
#   and/CC
#   (GPE Industry/NNP)
#   standards/NNS
#   ./.)
# (S
#   The/DT
#   design/NN
#   is/VBZ
#   exemplary/JJ
#   and/CC
#   meets/VBZ
#   (ORGANIZATION MOST/NNP)
#   learning/JJ
#   outcomes/NNS
#   at/IN
#   an/DT
#   exemplary/JJ
#   level/NN
#   ./.)
# (S
#   (GPE Clear/JJ)
#   demonstration/NN
#   and/CC
#   exemplary/JJ
#   awareness/NN
#   of/IN
#   (ORGANIZATION DW/NNP)
#   and/CC
#   (ORGANIZATION BI/NNP)
#   needs/VBZ
#   for/IN
#   industry/NN
#   ./.)
# (S
#   Most/JJS
#   design/NN
#   steps/NNS
#   clearly/RB
#   identified/VBN
#   and/CC
#   of/IN
#   exemplary/JJ
#   quality/NN
#   ./.)
# (S
#   Generally/RB
#   ,/,
#   you/PRP
#   needed/VBD
#   to/TO
#   consider/VB
#   more/JJR
#   depth/NN
#   or/CC
#   details/NNS
#   to/TO
#   one/CD
#   or/CC
#   m/VB
#   ore/JJR
#   sections/NNS
#   ./.)
# (S
#   You/PRP
#   may/MD
#   also/RB
#   have/VB
#   considered/VBN
#   provid/JJ
#   ing/VBG
#   more/RBR
#   complex/JJ
#   dimensions/NNS
#   to/TO
#   your/PRP$
#   fact/NN
#   table/NN
#   ./.)
# (S
#   (ORGANIZATION ICA/NNP)
#   Specification/NNP
#   (PERSON Annalisa/NNP Occhipinti/NNP Page/NNP)
#   |/VBD
#   7/CD
#   </IN
#   50/CD
#   Marks/NNS
#   :/:
#   (/(
#   0/CD
#   -34/NN
#   )/)
#   [/NN
#   inadequate/JJ
#   ]/VBZ
#   The/DT
#   submitted/JJ
#   work/NN
#   was/VBD
#   insufficiently/RB
#   well/RB
#   -developed/VBN
#   for/IN
#   this/DT
#   level/NN
#   of/IN
#   study/NN
#   and/CC
#   could/MD
#   be/VB
#   improved/VBN
#   substantially/RB
#   by/IN
#   using/VBG
#   m/NN
#   ore/RB
#   thoughtful/JJ
#   inspection/NN
#   and/CC
#   the/DT
#   use/NN
#   of/IN
#   more/RBR
#   DW/NNP
#   &/CC
#   BI/NNP
#   tools/NNS
#   ./.)
# (S
#   Detailed/VBN
#   assessment/JJ
#   criteria/NNS
#   –/VBP
#   (PERSON Main/NNP Report/NNP)
#   The/DT
#   following/VBG
#   detailed/JJ
#   assessment/JJ
#   criteria/NNS
#   have/VBP
#   been/VBN
#   provided/VBN
#   to/TO
#   help/VB
#   you/PRP
#   check/VB
#   you/PRP
#   have/VBP
#   included/VBN
#   the/DT
#   required/JJ
#   elements/NNS
#   in/IN
#   your/PRP$
#   (ORGANIZATION ICA/NNP)
#   ./.)
# (S
#   (ORGANIZATION Business/NN)
#   (ORGANIZATION Intelligence/NNP)
#   Report/NNP
#   A/NNP
#   )/)
#   Title/NNP
#   page/NN
#   and/CC
#   (PERSON Executive/NNP Summary/NNP)
#   •/VBD
#   The/DT
#   project/NN
#   has/VBZ
#   a/DT
#   title/NN
#   page/NN
#   with/IN
#   the/DT
#   title/NN
#   of/IN
#   the/DT
#   report/NN
#   ,/,
#   project/NN
#   and/CC
#   your/PRP$
#   details/NNS
#   •/VBP
#   The/DT
#   executive/NN
#   summary/NN
#   provides/VBZ
#   a/DT
#   clear/JJ
#   summary/NN
#   of/IN
#   the/DT
#   report/NN
#   •/VBD
#   The/DT
#   key/JJ
#   findings/NNS
#   are/VBP
#   presented/VBN
#   •/NNS
#   At/IN
#   least/JJS
#   one/CD
#   chart/NN
#   is/VBZ
#   reported/VBN
#   •/IN
#   The/DT
#   recommendations/NNS
#   are/VBP
#   included/VBN
#   B/NNP
#   )/)
#   Introduction/NNP
#   ,/,
#   (PERSON Data/NNP Sources/NNP)
#   ,/,
#   and/CC
#   (ORGANIZATION BI/NNP Questions/NNP)
#   •/NNP
#   There/EX
#   is/VBZ
#   a/DT
#   description/NN
#   of/IN
#   the/DT
#   data/NNS
#   used/VBN
#   in/IN
#   the/DT
#   model/NN
#   ./.)
# (S
#   •/IN
#   The/DT
#   data/NN
#   reported/VBD
#   in/IN
#   each/DT
#   table/NN
#   (/(
#   columns/NN
#   )/)
#   is/VBZ
#   described/VBN
#   •/IN
#   A/DT
#   link/NN
#   to/TO
#   the/DT
#   dataset/NN
#   ’/NNP
#   s/NN
#   source/NN
#   has/VBZ
#   been/VBN
#   included/VBN
#   •/JJ
#   Why/WRB
#   did/VBD
#   you/PRP
#   select/VB
#   this/DT
#   specific/JJ
#   dataset/NN
#   ?/.)
# (S
#   •/NN
#   Will/MD
#   this/DT
#   dataset/VB
#   help/NN
#   you/PRP
#   in/IN
#   developing/VBG
#   specific/JJ
#   business/NN
#   skills/NNS
#   ?/.)
# (S
#   •/VB
#   What/WP
#   questions/NNS
#   do/VBP
#   you/PRP
#   seek/VB
#   to/TO
#   answer/VB
#   with/IN
#   your/PRP$
#   BI/NNP
#   project/NN
#   ?/.)
# (S
#   •/IN
#   The/DT
#   questions/NNS
#   addressed/VBD
#   in/IN
#   the/DT
#   report/NN
#   are/VBP
#   included/VBN
#   •/NNP
#   Which/NNP
#   specific/JJ
#   features/NNS
#   are/VBP
#   you/PRP
#   going/VBG
#   to/TO
#   focus/VB
#   on/IN
#   ?/.)
# (S
#   •/NN
#   Does/VBZ
#   this/DT
#   dataset/NN
#   address/NN
#   the/DT
#   Big/NNP
#   Data/NNP
#   problem/NN
#   ?/.)
# (S
#   C/NNP
#   )/)
#   Finding/VBG
#   based/VBN
#   on/IN
#   analysis/NN
#   and/CC
#   evaluation/NN
#   •/NN
#   At/IN
#   least/JJS
#   three/CD
#   different/JJ
#   visuals/NNS
#   have/VBP
#   been/VBN
#   used/VBN
#   in/IN
#   (GPE Power/NNP)
#   BI/NNP
#   and/CC
#   the/DT
#   screenshots/NNS
#   are/VBP
#   provided/VBN
#   •/IN
#   There/EX
#   is/VBZ
#   a/DT
#   proper/JJ
#   justification/NN
#   for/IN
#   the/DT
#   use/NN
#   of/IN
#   such/JJ
#   visuals/NNS
#   •/VBP
#   The/DT
#   description/NN
#   of/IN
#   the/DT
#   data/NNS
#   presented/VBN
#   in/IN
#   the/DT
#   chart/NN
#   has/VBZ
#   been/VBN
#   reported/VBN
#   for/IN
#   at/IN
#   least/JJS
#   two/CD
#   charts/NNS
#   •/VBP
#   At/IN
#   least/JJS
#   one/CD
#   calculated/JJ
#   column/NN
#   or/CC
#   measure/NN
#   has/VBZ
#   been/VBN
#   included/VBN
#   in/IN
#   a/DT
#   visual/JJ
#   •/NN
#   The/DT
#   key/JJ
#   findings/NNS
#   from/IN
#   the/DT
#   visuals/NNS
#   created/VBN
#   are/VBP
#   reported/VBN
#   •/IN
#   A/DT
#   screenshot/NN
#   of/IN
#   the/DT
#   final/JJ
#   dashboard/NN
#   has/VBZ
#   been/VBN
#   provided/VBN
#   •/RBR
#   A/DT
#   new/JJ
#   type/NN
#   of/IN
#   chart/NN
#   (/(
#   not/RB
#   covered/VBN
#   in/IN
#   the/DT
#   lesson/NN
#   )/)
#   has/VBZ
#   been/VBN
#   included/VBN
#   in/IN
#   the/DT
#   report/NN
#   ./.)
# (S
#   (ORGANIZATION ICA/NNP)
#   Specification/NNP
#   (PERSON Annalisa/NNP Occhipinti/NNP Page/NNP)
#   |/VBD
#   8/CD
#   D/NNP
#   )/)
#   Conclusions/NNPS
#   and/CC
#   Recommendations/NNP
#   •/VBP
#   A/NNP
#   summary/NN
#   of/IN
#   the/DT
#   report/NN
#   is/VBZ
#   provided/VBN
#   •/JJ
#   Recommendations/NNS
#   based/VBN
#   on/IN
#   findings/NNS
#   have/VBP
#   been/VBN
#   included/VBN
#   ./.)
# (S
#   •/JJ
#   Personal/NNP
#   conclusions/NNS
#   have/VBP
#   been/VBN
#   included/VBN
#   Detailed/RBR
#   a/DT
#   ssessment/JJ
#   criteria/NN
#   -/:
#   Appendix/VBP
#   The/DT
#   following/VBG
#   detailed/JJ
#   assessment/JJ
#   criteria/NNS
#   have/VBP
#   been/VBN
#   provided/VBN
#   to/TO
#   help/VB
#   you/PRP
#   check/VB
#   that/IN
#   you/PRP
#   have/VBP
#   included/VBN
#   the/DT
#   required/JJ
#   elements/NNS
#   in/IN
#   your/PRP$
#   (ORGANIZATION ICA/NNP)
#   ./.)
# (S
#   (PERSON Business/NNP)
#   (ORGANIZATION Intelligent/NNP)
#   Report/NNP
#   –/NNP
#   Appendix/NNP
#   Sections/NNP
#   A/NNP
#   )/)
#   (PERSON Data/NNP Pre/NNP)
#   -Processing/NN
#   and/CC
#   (PERSON Data/NNP Cleansing/NNP Evidence/NNP)
#   of/IN
#   the/DT
#   data/NNS
#   pre/SYM
#   -/:
#   processing/NN
#   steps/NNS
#   ./.)
# (S
#   (GPE Include/NNP)
#   screenshots/NNS
#   of/IN
#   your/PRP$
#   Power/NNP
#   BI/NNP
#   project/NN
#   in/IN
#   your/PRP$
#   presentation/NN
#   to/TO
#   illustrate/VB
#   the/DT
#   effect/NN
#   of/IN
#   each/DT
#   pre/NN
#   -processing/VBG
#   step/NN
#   ./.)
# (S
#   Is/VBZ
#   there/EX
#   any/DT
#   evidence/NN
#   of/IN
#   steps/NNS
#   performed/VBN
#   to/TO
#   cleanse/VB
#   the/DT
#   data/NNS
#   ?/.)
# (S
#   For/IN
#   example/NN
#   :/:
#   •/NN
#   Removing/NNP
#   NAs/NNP
#   ,/,
#   •/NNP
#   Renaming/NNP
#   columns/NN
#   •/NN
#   Changing/NNP
#   data/NNS
#   types/NNS
#   •/VBP
#   Removing/VBG
#   errors/NNS
#   •/VBP
#   Removing/VBG
#   columns/NN
#   •/NNP
#   Merging/NNP
#   tables/NNS
#   etc/FW
#   ./.)
# (S
#   B/NNP
#   )/)
#   (PERSON Data/NNP Modelling/NNP)
#   –/NNP
#   Star/NNP
#   (PERSON Schema/NNP Facts/NNP)
#   and/CC
#   (PERSON Dimensions/NNP)
#   A/NNP
#   description/NN
#   of/IN
#   the/DT
#   data/NNS
#   modelling/NN
#   process/NN
#   ./.)
# (S
#   You/PRP
#   should/MD
#   include/VB
#   screenshots/NNS
#   of/IN
#   the/DT
#   data/NNS
#   model/NN
#   from/IN
#   your/PRP$
#   Power/NNP
#   BI/NNP
#   project/NN
#   to/TO
#   illustrate/VB
#   the/DT
#   effect/NN
#   of/IN
#   the/DT
#   data/NNS
#   modelling/NN
#   process/NN
#   ./.)
# (S
#   If/IN
#   your/PRP$
#   database/NN
#   is/VBZ
#   already/RB
#   well/RB
#   -structured/VBN
#   and/CC
#   it/PRP
#   does/VBZ
#   not/RB
#   need/VB
#   any/DT
#   modification/NN
#   ,/,
#   show/VBP
#   the/DT
#   steps/NNS
#   required/VBN
#   in/IN
#   this/DT
#   section/NN
#   by/IN
#   deleting/VBG
#   at/IN
#   least/JJS
#   one/CD
#   relationship/NN
#   and/CC
#   show/NN
#   that/IN
#   you/PRP
#   can/MD
#   perform/VB
#   the/DT
#   steps/NNS
#   for/IN
#   adding/VBG
#   relationships/NNS
#   in/IN
#   (GPE Power/NNP)
#   BI/NNP
#   ./.)
# (S
#   This/DT
#   will/MD
#   meet/VB
#   the/DT
#   first/JJ
#   There/EX
#   is/VBZ
#   evidence/NN
#   of/IN
#   some/DT
#   steps/NNS
#   performed/VBD
#   to/TO
#   develop/VB
#   a/DT
#   well/NN
#   -structured/VBN
#   data/NNS
#   model/NN
#   ,/,
#   such/JJ
#   as/IN
#   :/:
#   •/NN
#   Creating/VBG
#   new/JJ
#   relationships/NNS
#   •/VBP
#   Modifying/VBG
#   relationships/NNS
#   Splitting/VBG
#   big/JJ
#   tables/NNS
#   to/TO
#   normalise/VB
#   data/NNS
#   ./.)
# (S
#   (ORGANIZATION ICA/NNP)
#   Specification/NNP
#   (PERSON Annalisa/NNP Occhipinti/NNP Page/NNP)
#   |/VBD
#   9/CD
#   target/NN
#   in/IN
#   this/DT
#   section/NN
#   (/(
#   creating/VBG
#   new/JJ
#   relationships/NNS
#   )/)
#   ./.)
# (S
#   C/NNP
#   )/)
#   (ORGANIZATION DAX/NNP)
#   and/CC
#   M/NNP
#   Language/NNP
#   •/NNP
#   Different/NNP
#   formulae/NNS
#   have/VBP
#   been/VBN
#   used/VBN
#   in/IN
#   the/DT
#   analysis/NN
#   (/(
#   either/CC
#   (ORGANIZATION DAX/NNP)
#   or/CC
#   M/NNP
#   language/NN
#   )/)
#   •/NN
#   There/EX
#   is/VBZ
#   a/DT
#   clear/JJ
#   understanding/NN
#   of/IN
#   how/WRB
#   the/DT
#   formulae/NN
#   have/VBP
#   been/VBN
#   used/VBN
#   ./.)
# (S
#   This/DT
#   is/VBZ
#   shown/VBN
#   by/IN
#   providing/VBG
#   a/DT
#   clear/JJ
#   written/VBN
#   explanation/NN
#   of/IN
#   how/WRB
#   the/DT
#   applied/JJ
#   formula/NN
#   works/NNS
#   ./.)
# (S
#   •/JJ
#   New/NNP
#   calculated/VBD
#   columns/NNS
#   have/VBP
#   been/VBN
#   added/VBN
#   to/TO
#   the/DT
#   model/NN
#   New/NNP
#   measures/NNS
#   have/VBP
#   been/VBN
#   added/VBN
#   to/TO
#   the/DT
#   model/NN
#   D/NNP
#   )/)
#   (PERSON Dashboard/NNP Design/NNP)
#   •/NNP
#   Describe/NNP
#   the/DT
#   (ORGANIZATION Power/NNP)
#   BI/NNP
#   dashboard/NN
#   (/(
#   full/JJ
#   collection/NN
#   of/IN
#   visuals/NNS
#   )/)
#   and/CC
#   how/WRB
#   the/DT
#   content/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Power/NNP)
#   BI/NNP
#   pages/NNS
#   is/VBZ
#   organised/VBN
#   ./.)
# (S
#   •/VB
#   A/DT
#   screenshot/NN
#   of/IN
#   all/PDT
#   the/DT
#   pages/NNS
#   of/IN
#   the/DT
#   (ORGANIZATION Dashboard/NNP)
#   must/MD
#   be/VB
#   provided/VBN
#   ./.)
# (S
#   (ORGANIZATION ICA/NNP)
#   Specification/NNP
#   (PERSON Annalisa/NNP Occhipinti/NNP Page/NNP)
#   |/POS
#   10/CD
#   (ORGANIZATION Business/NNP Intelligence/NNP Dataset/NNP)
#   s/NN
#   For/IN
#   your/PRP$
#   (ORGANIZATION ICA/NNP)
#   ,/,
#   you/PRP
#   can/MD
#   use/VB
#   a/DT
#   data/NN
#   set/NN
#   of/IN
#   your/PRP$
#   choice/NN
#   among/IN
#   the/DT
#   ones/NNS
#   provided/VBN
#   on/IN
#   (ORGANIZATION Blackboard/NNP)
#   ./.)
# (S
#   We/PRP
#   do/VBP
#   not/RB
#   mind/VB
#   which/WDT
#   dataset/NN
#   you/PRP
#   choose/VBP
#   but/CC
#   do/VBP
#   choose/VB
#   one/CD
#   in/IN
#   the/DT
#   first/JJ
#   weeks/NNS
#   of/IN
#   the/DT
#   semester/NN
#   ./.)
# (S
#   In/IN
#   the/DT
#   module/NN
#   ,/,
#   you/PRP
#   will/MD
#   also/RB
#   be/VB
#   introduced/VBN
#   to/TO
#   different/JJ
#   data/NNS
#   sources/NNS
#   ./.)
# (S
#   S/NNP
#   ome/JJ
#   examples/NNS
#   of/IN
#   database/NN
#   s/NN
#   are/VBP
#   listed/VBN
#   below/IN
#   ./.)
# (S
#   •/NN
#   (ORGANIZATION AdventureWorks/NNP)
#   database/NN
#   (/(
#   you/PRP
#   can/MD
#   find/VB
#   this/DT
#   database/NN
#   on/IN
#   (ORGANIZATION Blackboard/NNP)
#   in/IN
#   the/DT
#   (ORGANIZATION Extra/NNP)
#   Resources/NNP
#   folder/NN
#   )/)
#   •/NN
#   (PERSON Norhtwind/NNP Database/NNP)
#   (/(
#   to/TO
#   access/NN
#   this/DT
#   dataset/NN
#   ,/,
#   click/JJ
#   Get/NNP
#   Data/NNP
#   on/IN
#   (PERSON Power/NNP BI/NNP)
#   ,/,
#   then/RB
#   look/NN
#   for/IN
#   (ORGANIZATION OData/NNP Feed/NNP)
#   type/NN
#   and/CC
#   insert/VB
#   the/DT
#   following/JJ
#   link/NN
#   https/NN
#   :/:
#   //services.odata.org/V3/Northwind/Northwind.svc//SYM
#   -/:
#   you/PRP
#   can/MD
#   then/RB
#   select/VB
#   the/DT
#   columns/NN
#   that/IN
#   you/PRP
#   prefer/VBP
#   )/)
#   You/PRP
#   can/MD
#   select/VB
#   one/CD
#   of/IN
#   the/DT
#   datasets/NNS
#   provided/VBD
#   on/IN
#   (ORGANIZATION Blackboard/NNP)
#   in/IN
#   the/DT
#   (ORGANIZATION Extra/NNP Resources/NNPS)
#   folder/NN
#   ./.)
# (S
#   Below/IN
#   are/VBP
#   research/NN
#   and/CC
#   government/NN
#   websites/NNS
#   where/WRB
#   you/PRP
#   can/MD
#   also/RB
#   find/VB
#   and/CC
#   select/VB
#   suitable/JJ
#   data/NNS
#   set/VBD
#   to/TO
#   develop/VB
#   a/DT
#   Business/NN
#   I/PRP
#   ntelligence/VBP
#   solution/NN
#   using/VBG
#   (ORGANIZATION PowerBI/NNP)
#   ./.)
# (S
#   If/IN
#   you/PRP
#   select/VBP
#   one/CD
#   of/IN
#   the/DT
#   datasets/NNS
#   from/IN
#   the/DT
#   websites/NNS
#   below/IN
#   ,/,
#   please/VB
#   make/VB
#   sure/JJ
#   that/IN
#   it/PRP
#   has/VBZ
#   enough/JJ
#   columns/NNS
#   and/CC
#   rows/NNS
#   to/TO
#   develop/VB
#   a/DT
#   well/RB
#   -structured/JJ
#   business/NN
#   intelligence/NN
#   model/NN
#   ./.)
# (S
#   •/JJ
#   (PERSON Kaggle/NNP)
#   •/NNP
#   (PERSON Machine/NNP Learning/NNP Repository/NNP)
#   –/NNP
#   UCI/NNP
#   •/NNP
#   GitHub/NNP
#   •/JJ
#   Government/NNP
#   Data/NNP
#   •/NNP
#   GitHub/NNP
#   –/NNP
#   Second/NNP
#   repository/NN)

# %%
chunked_text[56]
# Out:
# Tree('S', [('This', 'DT'), ('will', 'MD'), ('assess', 'VB'), ('the', 'DT'), ('student', 'NN'), ('’', 'NNP'), ('s', 'VBZ'), ('ability', 'NN'), ('to', 'TO'), ('demonstrate', 'VB'), ('data', 'NNS'), ('analytics', 'NNS'), (',', ','), ('visualisati', 'NN'), ('on', 'IN'), ('and', 'CC'), ('reporting', 'VBG'), ('skills', 'NNS'), ('required', 'VBN'), ('to', 'TO'), ('support', 'VB'), ('any', 'DT'), Tree('ORGANIZATION', [('Business', 'NNP'), ('Intelligence', 'NNP')]), ('solution', 'NN'), ('(', '('), ('assess', 'JJ'), ('Learning', 'NNP'), ('Outcome', 'NNP'), ('1', 'CD'), (',', ','), ('3', 'CD'), (',', ','), ('4', 'CD'), (',', ','), ('5', 'CD'), (',', ','), ('6', 'CD'), ('&', 'CC'), ('7', 'CD'), (')', ')'), ('A', 'DT'), ('template', 'NN'), ('with', 'IN'), ('the', 'DT'), ('sections', 'NNS'), ('listed', 'VBN'), ('above', 'RB'), ('is', 'VBZ'), ('available', 'JJ'), ('on', 'IN'), Tree('ORGANIZATION', [('Blackboard', 'NNP')]), ('.', '.')])
